# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (0.1.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.17 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (0.0.17)
# Requirement already satisfied: langchain-core<0.2,>=0.1.16 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (0.1.18)
# Requirement already satisfied: langsmith<0.1,>=0.0.83 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (0.0.86)
# Requirement already satisfied: numpy<2,>=1 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2,>=0.1.16->langchain) (4.2.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2,>=0.1.16->langchain) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.16->langchain) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.16->langchain) (1.1.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (1.11.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from openai) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from openai) (2.6.1)
# Requirement already satisfied: sniffio in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from openai) (4.7.1)
# Requirement already satisfied: idna>=2.8 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (1.1.3)
# Requirement already satisfied: certifi in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->openai) (2.16.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyPDF2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (3.0.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from PyPDF2) (4.7.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.4-cp39-cp39-macosx_11_0_arm64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 8.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.7.4
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tiktoken
#   Obtaining dependency information for tiktoken from https://files.pythonhosted.org/packages/22/fe/cbd92a4a203567c069d766d573e9f9a44b05beafe88d927b7a78b00d5310/tiktoken-0.5.2-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading tiktoken-0.5.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting regex>=2022.1.18 (from tiktoken)
#   Obtaining dependency information for regex>=2022.1.18 from https://files.pythonhosted.org/packages/c5/b3/f5c06f5ebb865a63ea775828038d5ce48263806616e4ad5092ff50e22c93/regex-2023.12.25-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading regex-2023.12.25-cp39-cp39-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken) (2024.2.2)
# Downloading tiktoken-0.5.2-cp39-cp39-macosx_11_0_arm64.whl (955 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 955.6/955.6 kB 7.6 MB/s eta 0:00:00a 0:00:01
# Downloading regex-2023.12.25-cp39-cp39-macosx_11_0_arm64.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.0/291.0 kB 7.3 MB/s eta 0:00:0000:01
# Installing collected packages: regex, tiktoken
# Successfully installed regex-2023.12.25 tiktoken-0.5.2
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
pdfreader = PdfReader('Interview questions.pdf')

# %%
from typing_extensions import Concatenate
raw_text=''
for i,page in enumerate(pdfreader.pages):
    content=page.extract_text()
    if content:
        raw_text+= content

# %%
raw_text
# Out:
# 'Follow Steve N ouri for more AI and Data science posts: https://lnkd.in/gZu463 X Data Science Interview Questions  \n \nStatistics:  \n1. What is the Central Limit Theorem and wh y is it important ? \n“Suppose that we are interested in estimating the average height among all people. Collecting data for \nevery person in the world is impossible. While we can’t obtain a height measurement from everyone in the \npopulation, we can still sample some people. The  question now becomes, what can we say about the \naverage height of the entire population given a single sample. The Central Limit Theorem addresses this \nquestion exactly.”  Read more  here . \n2. What is sampling? How many sampling methods do you know ? \n“Data sampling is a statistical analysis technique used to select, manipulate and analyze a representative \nsubset of data points to identify patterns and trends in the l arger data set being examined.”  Read the full \nanswer  here . \n3. What is the difference between type I vs type II error ? \n“A type I error occurs when the null hypo thesis is true, but is rejected.  A type II error occurs when the null \nhypothesis is false, but erroneously fails to be rejected.”  Read the full answer  here . \n4. What is linear regression? What do the terms p -value, coefficient, and r -squared \nvalue mean? What is the significance of each of these components ? \nA linear regression is a good tool for quick predictive analysis: for example, the price o f a house depends \non a myriad of factors, such as its size or its location. In order to see the relationship between these \nvariables, we need to build a linear regression, which predicts the line of best fit between them and can \nhelp conclude whether or no t these two factors have a positive or negative relationship.  Read \nmore  here  and here.  \n5. What are the assumptions required for linear regression ? \nThere are four major assumptions: 1. There is a linear relationship between the dependent variables and \nthe regres sors, meaning the model you are creating actually fits the data, 2. The errors or residuals of the \ndata are normally distributed and independent from each other, 3. There is minimal multicollinearity \nbetween explanatory variables, and 4. Homoscedasticity. This means the variance around the regression \nline is the same for all values of the predictor variable . \n6. What is a statistical interaction ? \n”Basically, an interaction is when the effect of one factor (input variable) on the dependent variable (output \nvaria ble) differs among levels of another factor.”  Read more  here . \n7. What is selection bias ? \n“Selection (or ‘sampling’) bias occurs in an  ‘active,’ sense when the sample data that is gathered and \nprepared for modeling has characteristics that are not representative of the true, future population of cases Follow Steve N ouri for more AI and Data science posts: https://lnkd.in/gZu463 X the model will see. That is, active selection bias occurs when a subset of the data are  systematically (i.e., \nnon-randomly) excluded from analysis.”  Read more  here . \n8. What is an example of a data set with a non -Gaussian distribution ? \n“The Gaussian distribution is part of the Exponential family of distributions, but there are a lot more of \nthem, with the same sort of ease of use, in many cases, and if the person doing th e machine learning has \na solid grounding in statistics, they can be utilized where appropriate.”  Read more  here . \n9. What is the Binomial Probability Formula ? \n“The binomial distribution consists of the probabilities of each of the possible numbers of successes on N \ntrials for independent events that each have a pro bability of π (the Greek letter pi) of occurring.”  Read more   \nData Science  : \nQ1. What is Data Science? List the differences between supervised and unsupervised \nlearning.  \nData Science is a blend of various tools, algorithms, and machine learning principles wi th the goal to discove ...

# %%
text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 800,
    chunk_overlap  = 200,
    length_function = len,
)
texts = text_splitter.split_text(raw_text)

# %%
embeddings = OpenAIEmbeddings()
# Out:
# /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.1.0 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
document_search = FAISS.from_texts(texts, embeddings)

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI

# %%
chain = load_qa_chain(OpenAI(), chain_type="stuff")
# Out:
# /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
query = " "
docs = document_search.similarity_search(query)
chain.run(input_documents=docs, question=query)

# %%
from langchain.document_loaders import OnlinePDFLoader

# %%
loader = OnlinePDFLoader("https://arxiv.org/pdf/1706.03762.pdf")

# %%
# !pip install unstructured
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unstructured
#   Obtaining dependency information for unstructured from https://files.pythonhosted.org/packages/3e/87/cb84dcd87caa63e8b08dfb4a8b7421556f0b1e14720604674b8be3941776/unstructured-0.12.3-py3-none-any.whl.metadata
#   Downloading unstructured-0.12.3-py3-none-any.whl.metadata (26 kB)
# Collecting chardet (from unstructured)
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Collecting lxml (from unstructured)
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/f6/c8/ccdf3ac62f318a14a05a6a4fd6bb9de60014ef39c100ec605203be9be85b/lxml-5.1.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading lxml-5.1.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting nltk (from unstructured)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.7 MB/s eta 0:00:0000:0100:01
# Collecting tabulate (from unstructured)
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: requests in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured) (2.31.0)
# Collecting beautifulsoup4 (from unstructured)
#   Obtaining dependency information for beautifulsoup4 from https://files.pythonhosted.org/packages/b1/fe/e8c672695b37eecc5cbf43e1d0638d88d66ba3a44c4d321c796f4e59167f/beautifulsoup4-4.12.3-py3-none-any.whl.metadata
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting emoji (from unstructured)
#   Obtaining dependency information for emoji from https://files.pythonhosted.org/packages/98/00/00d56e704d69cee4a92b1d517676579b4af5f2f8bc72946c464a504705b2/emoji-2.10.1-py2.py3-none-any.whl.metadata
#   Downloading emoji-2.10.1-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: dataclasses-json in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured) (0.6.4)
# Collecting python-iso639 (from unstructured)
#   Obtaining dependency information for python-iso639 from https://files.pythonhosted.org/packages/01/62/2fed44ba10fe805345fb0e9c46c7f8dcdaf1bffd642f051fcc3db9bf55d8/python_iso639-2024.2.7-py3-none-any.whl.metadata
#   Downloading python_iso639-2024.2.7-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 8.8 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured) (1.25.2)
# Collecting rapidfuzz (from unstructured)
#   Obtaining dependency information for rapidfuzz from https://files.pythonhosted.org/packages/77/bb/549a9f0ca5455847340f37041adae5a2b6c1733519d50cd9f25f855b7f01/rapidfuzz-3.6.1-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading rapidfuzz-3.6.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured) (4.7.1)
# Collecting unstructured-client>=0.15.1 (from unstructured)
#   Obtaining dependency information for unstructured-client>=0.15.1 from https://files.pythonhosted.org/packages/a6/07/6e0fba885472decf691bb70818858c7996e0509d55c5001546e967614301/unstructured_client-0.18.0-py3-none-any.whl.metadata
#   Downloading unstructured_client-0.18.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting wrapt (from unstructured)
#   Obtaining dependency information for wrapt from https://files.pythonhosted.org/packages/4a/cc/3402bcc897978be00fef608cd9e3e39ec8869c973feeb5e1e277670e5ad2/wrapt-1.16.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading wrapt-1.16.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi>=2023.7.22 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured-client>=0.15.1->unstructured) (2024.2.2)
# Requirement already satisfied: charset-normalizer>=3.2.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured-client>=0.15.1->unstructured) (3.3.2)
# Collecting dataclasses-json-speakeasy>=0.5.11 (from unstructured-client>=0.15.1->unstructured)
#   Obtaining dependency information for dataclasses-json-speakeasy>=0.5.11 from https://files.pythonhosted.org/packages/57/5b/2002d3da4fc37c567287cd89fb08b43c1fb130ce0d757bd3e8f61b1a1f94/dataclasses_json_speakeasy-0.5.11-py3-none-any.whl.metadata
#   Downloading dataclasses_json_speakeasy-0.5.11-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: idna>=3.4 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured-client>=0.15.1->unstructured) (3.6)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client>=0.15.1->unstructured)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: marshmallow>=3.19.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured-client>=0.15.1->unstructured) (3.20.2)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured-client>=0.15.1->unstructured) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured-client>=0.15.1->unstructured) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured-client>=0.15.1->unstructured) (2.8.2)
# Collecting six>=1.16.0 (from unstructured-client>=0.15.1->unstructured)
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-inspect>=0.9.0 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured-client>=0.15.1->unstructured) (0.9.0)
# Requirement already satisfied: urllib3>=1.26.18 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from unstructured-client>=0.15.1->unstructured) (2.2.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->unstructured)
#   Obtaining dependency information for soupsieve>1.2 from https://files.pythonhosted.org/packages/4c/f3/038b302fdfbe3be7da016777069f26ceefe11a681055ea1f7817546508e3/soupsieve-2.5-py3-none-any.whl.metadata
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting click (from nltk->unstructured)
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from nltk->unstructured) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from nltk->unstructured) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/abelabykuriakose/Library/Python/3.9/lib/python/site-packages (from nltk->unstructured) (4.66.1)
# Downloading unstructured-0.12.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.9 MB/s eta 0:00:0000:0100:01
# Downloading unstructured_client-0.18.0-py3-none-any.whl (21 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 7.3 MB/s eta 0:00:00
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 7.3 MB/s eta 0:00:00
# Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 8.1 MB/s eta 0:00:00a 0:00:01
# Downloading lxml-5.1.0-cp39-cp39-macosx_11_0_arm64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 8.8 MB/s eta 0:00:0000:0100:01
# Downloading python_iso639-2024.2.7-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 7.7 MB/s eta 0:00:00
# Downloading rapidfuzz-3.6.1-cp39-cp39-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.7 MB/s eta 0:00:00a 0:00:01
# Downloading wrapt-1.16.0-cp39-cp39-macosx_11_0_arm64.whl (38 kB)
# Downloading dataclasses_json_speakeasy-0.5.11-py3-none-any.whl (28 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=4fbe73d86795f41c6721c6628dd2a72a29dc865b2496e8c8591776ac9d28c5ab
#   Stored in directory: /Users/abelabykuriakose/Library/Caches/pip/wheels/d1/c1/d9/7e068de779d863bc8f8fc9467d85e25cfe47fa5051fff1a1bb
# Successfully built langdetect
# Installing collected packages: filetype, wrapt, tabulate, soupsieve, six, rapidfuzz, python-magic, python-iso639, lxml, jsonpath-python, emoji, click, chardet, backoff, nltk, langdetect, dataclasses-json-speakeasy, beautifulsoup4, unstructured-client, unstructured
# Successfully installed backoff-2.2.1 beautifulsoup4-4.12.3 chardet-5.2.0 click-8.1.7 dataclasses-json-speakeasy-0.5.11 emoji-2.10.1 filetype-1.2.0 jsonpath-python-1.0.6 langdetect-1.0.9 lxml-5.1.0 nltk-3.8.1 python-iso639-2024.2.7 python-magic-0.4.27 rapidfuzz-3.6.1 six-1.16.0 soupsieve-2.5 tabulate-0.9.0 unstructured-0.12.3 unstructured-client-0.18.0 wrapt-1.16.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
data = loader.load()

# %%
embeddings = OpenAIEmbeddings()

# %%
from langchain.indexes import VectorstoreIndexCreator
index = VectorstoreIndexCreator().from_loaders([loader])

# %%
query = "Explain me about Attention is all you need"
index.query(query)
